# %%
library(tidyverse)
library(here)
library(microbiome)
source("https://raw.githubusercontent.com/HenrikEckermann/in_use/master/reporting.R")
load(here("data/cc_analyses_workspace.RData"))

# %%
biplot(pseq.clr)
# Out:
# Warning message:
# “`as.tibble()` is deprecated, use `as_tibble()` (but mind the new semantics).
# This warning is displayed once per session.”Warning message:
# “`as_data_frame()` is deprecated, use `as_tibble()` (but mind the new semantics).
# This warning is displayed once per session.”Warning message in class(x) <- c(subclass, tibble_class):
# “Setting class(x) to multiple strings ("tbl_df", "tbl", ...); result will no longer be an S4 object”Warning message:
# “Removed 196 rows containing missing values (geom_point).”Warning message:
# “Removed 196 rows containing missing values (geom_point).”
# [[1]]
#
# [[2]]
# plot without title
# plot without title
