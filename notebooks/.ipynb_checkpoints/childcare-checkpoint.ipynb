# %%
library(HITChipDB)
library(microbiome)
library(tidyverse)
library(here)

# load data and helper functions
source(here("R/bayesian_helper.R"))
load(here("data/data_transfer.RData"))
source(here("R/read.R"))

# %%
meta_new <- data_transfer[, 1:8]
# create variable subject_id
sample_data(genus)$subject_id <- 
    substring(sample_data(genus)$unique.subjectID, 19, 23)

# %%
dfcc <- subset_samples(genus, sample %in% meta_new$sample)
sample_data(dfcc)$time <- meta_new$time
sample_data(dfcc)$cc <- meta_new$cc
sample_data(dfcc)$age_d_s <- meta_new$age_d_s
sample_data(dfcc)$bf_count_s <- meta_new$bf_count_s

# %%
sample_data(dfcc) <- 
    sample_data(dfcc)[, c("subject_id", "sample", "time", "cc", "bf_count_s", "age_d_s")]

# %%
colnames(sample_data(dfcc))
# Out:
# [1] "subject_id" "sample"     "time"       "cc"         "bf_count_s"
# [6] "age_d_s"

# %%
sample_data(dfcc)
# Out:
#          subject_id sample   time cc  bf_count_s  age_d_s
# sa_11183 202        sa_11183 post no   0.43948544  0.0320946
# sa_5986  202        sa_5986  post yes -1.65710371  0.0320946
# sa_11180 204        sa_11180 post yes  0.64565004  0.5275689
# sa_7451  204        sa_7451  post yes  0.09005391  0.4795079
# sa_832   207        sa_832   post no   0.78891696  0.1311895
# sa_10000 207        sa_10000 pre  yes  0.47442859 -0.9093066
# sa_9030  210        sa_9030  post no   0.43948544  0.7753060
# sa_5512  210        sa_5512  pre  no   0.70544165 -1.4543283
# sa_3434  211        sa_3434  pre  no   0.85880327 -1.1074963
# sa_2298  211        sa_2298  pre  yes  0.59964155 -0.4633797
# sa_1030  213        sa_1030  post no           NA  0.8248535
# sa_8061  213        sa_8061  pre  yes  0.64062696  1.0230432
# sa_3212  216        sa_3212  post yes -1.65710371  1.5680649
# sa_10230 216        sa_10230 post yes -1.65710371  0.5275689
# ...

# %%
# Out:
#          My.SQL.ID projectName         groupcode timepoint time sample.type
# sa_2288  NBS_201   NIJMEGEN BABY STUDY NBS6      10        2193 fecal
# sa_3262  NBS_201_4 NIJMEGEN BABY STUDY PN4        4          28 fecal
# sa_1746  NBS_202   NIJMEGEN BABY STUDY NBS6      10        2193 fecal
# sa_7099  NBS_202_2 NIJMEGEN BABY STUDY PN2        2           7 fecal
# sa_9870  NBS_202_3 NIJMEGEN BABY STUDY PN3        3          14 fecal
# sa_10996 NBS_202_4 NIJMEGEN BABY STUDY PN4        4          28 fecal
# sa_11183 NBS_202_5 NIJMEGEN BABY STUDY KDV1       5          75 fecal
# sa_5986  NBS_202_9 NIJMEGEN BABY STUDY KDV5       9         105 fecal
# sa_476   NBS_203   NIJMEGEN BABY STUDY NBS6      10        2193 fecal
# sa_11460 NBS_203_4 NIJMEGEN BABY STUDY PN4        4          28 fecal
# sa_10973 NBS_204   NIJMEGEN BABY STUDY NBS6      10        2193 fecal
# sa_5010  NBS_204_2 NIJMEGEN BABY STUDY PN2        2           7 fecal
# ...

# %%
meta_new
# Out:
#     subject_id time cc  age_d  age_d_s     bf_count   bf_count_s
# 1   207        post no   98.00  0.0320946   6.0000000  0.43948544
# 2   388        post yes  98.00  0.0320946   0.0000000 -1.65710371
# 3   381        post yes 108.00  0.5275689   6.5900000  0.64565004
# 4   283        post yes 107.03  0.4795079   5.0000000  0.09005391
# 5   216        post no  100.00  0.1311895   7.0000000  0.78891696
# 6   277        pre  yes  79.00 -0.9093066   6.1000000  0.47442859
# 7   373        post no  113.00  0.7753060   6.0000000  0.43948544
# 8   245        pre  no   68.00 -1.4543283   6.7611111  0.70544165
# 9   311        pre  no   75.00 -1.1074963   7.2000000  0.85880327
# 10  213        pre  yes  88.00 -0.4633797   6.4583333  0.59964155
# 11  443        post no  114.00  0.8248535          NA          NA
# 12  354        pre  yes 118.00  1.0230432   6.5756250  0.64062696
# 13  422        post yes 129.00  1.5680649   0.0000000 -1.65710371
# ...
